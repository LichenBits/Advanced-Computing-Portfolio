# %%
import pandas as pd
import matplotlib as plt


dataframe = pd.read_csv("oecd_bli_2015.csv")

dataframe.hist(bins=50, figsize=(20,15))
#dataframe.info()

#print(dataframe.head())

#dataframe['Country'].value_counts()
# Out:
# array([[<AxesSubplot:title={'center':'PowerCode Code'}>,
#         <AxesSubplot:title={'center':'Reference Period Code'}>],
#        [<AxesSubplot:title={'center':'Reference Period'}>,
#         <AxesSubplot:title={'center':'Value'}>]], dtype=object)
